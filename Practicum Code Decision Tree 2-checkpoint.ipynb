# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import r2_score, confusion_matrix, classification_report, roc_curve, auc, RocCurveDisplay, ConfusionMatrixDisplay, accuracy_score, mean_squared_error
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split
from sklearn import tree
from pydotplus import graph_from_dot_data

# %%
df = pd.read_csv('Invistico_Airline_Original_Copy.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  object
#  3   Type of Travel                     129880 non-null  object
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Seat comfort                       129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Age                                129880 non-null  int64
#  9   Food and drink                     129880 non-null  int64
#  10  Gate location                      129880 non-null  int64
#  11  Inflight wifi service              129880 non-null  int64
#  12  Inflight entertainment             129880 non-null  int64
#  13  Online support                     129880 non-null  int64
#  14  Ease of Online booking             129880 non-null  int64
#  15  On-board service                   129880 non-null  int64
#  16  Leg room service                   129880 non-null  int64
#  17  Baggage handling                   129880 non-null  int64
#  18  Checkin service                    129880 non-null  int64
#  19  Cleanliness                        129880 non-null  int64
#  20  Online boarding                    129880 non-null  int64
#  21  Departure Delay in Minutes         129880 non-null  int64
#  22  Arrival Delay in Minutes           129487 non-null  float64
# dtypes: float64(1), int64(17), object(5)
# memory usage: 22.8+ MB

# %%
#check for null values
df.isna().sum()
# Out:
# satisfaction                           0
# Gender                                 0
# Customer Type                          0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Age                                    0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# dtype: int64

# %%
#delete row method
df_delete_row = df.dropna(axis=0)

# %%
#validate that null values were removed
df_delete_row.isna().sum(axis=0)
# Out:
# satisfaction                         0
# Gender                               0
# Customer Type                        0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Age                                  0
# Food and drink                       0
# Gate location                        0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Online boarding                      0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %%
#in column 'satisfaction', replace "satisfied" == 1 and "dissatisfied" == 0
df_delete_row['satisfaction'] = df_delete_row['satisfaction'].replace({'satisfied': 1, 'dissatisfied': 0})
df_delete_row.head()
# Out:
# C:\Users\mblus\AppData\Local\Temp\ipykernel_12536\110920926.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_delete_row['satisfaction'] = df_delete_row['satisfaction'].replace({'satisfied': 1, 'dissatisfied': 0})
#    satisfaction  Gender   Customer Type   Type of Travel     Class  \
# 0             1  Female  Loyal Customer  Personal Travel       Eco
# 1             1    Male  Loyal Customer  Personal Travel  Business
# 2             1  Female  Loyal Customer  Personal Travel       Eco
# 3             1  Female  Loyal Customer  Personal Travel       Eco
# 4             1  Female  Loyal Customer  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  Age  \
# 0              265             0                                  0   65
# 1             2464             0                                  0   47
# 2             2138             0                                  0   15
# 3              623             0                                  0   60
# 4              354             0                                  0   70
#
#    Food and drink  Gate location  Inflight wifi service  \
# 0               0              2                      2
# 1               0              3                      0
# 2               0              3                      2
# 3               0              3                      3
# 4               0              3                      4
#
#    Inflight entertainment  Online support  Ease of Online booking  \
# 0                       4               2                       3
# 1                       2               2                       3
# 2                       0               2                       2
# 3                       4               3                       1
# 4                       3               4                       2
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 3                 0                 3                5
# 1                 4                 4                 4                2
# 2                 3                 3                 4                4
# 3                 1                 0                 1                4
# 4                 2                 0                 2                4
#
#    Cleanliness  Online boarding  Departure Delay in Minutes  \
# 0            3                2                           0
# 1            3                2                         310
# 2            4                2                           0
# 3            1                3                           0
# 4            2                5                           0
#
#    Arrival Delay in Minutes
# 0                       0.0
# 1                     305.0
# 2                       0.0
# 3                       0.0
# 4                       0.0

# %%
#detect and eliminate outliers of continuous variables
df_copy = df_delete_row.copy() # copy data for safe keeping
var_list = ['Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes'] #list of variables for cycling through the loop

for var in var_list:
    iqr = df_copy[var_list].quantile(0.75)[var] - df_copy[var_list].quantile(0.25)[var] #establish the iqr by subracting the 25% from 75%
    if not np.isnan(iqr): #if not null, then perform the following
        ub = df_copy[var_list].quantile(0.75)[var] + 1.5*iqr # cal the upper bound
        lb = df_copy[var_list].quantile(0.25)[var] - 1.5*iqr # cal the lower bound
        df_copy = df_copy[(df_copy[var] <= ub) & (df_copy[var] >= lb)] # leave the values that are less than the ub and greater than the lb and resave in df_copy
    
print(df_delete_row.shape)
print(df_copy.shape)
# Out:
# (129487, 23)
# (94448, 23)

# %%
cat_var = ["Customer Type","Type of Travel","Class", "Gender"] #list out all of the categorical variables that need dummy encoding
df_cat = pd.get_dummies(df_copy, columns=cat_var, drop_first=True)
df_cat.head()
# Out:
#    satisfaction  Flight Distance  Seat comfort  \
# 0             1              265             0
# 2             1             2138             0
# 3             1              623             0
# 4             1              354             0
# 5             1             1894             0
#
#    Departure/Arrival time convenient  Age  Food and drink  Gate location  \
# 0                                  0   65               0              2
# 2                                  0   15               0              3
# 3                                  0   60               0              3
# 4                                  0   70               0              3
# 5                                  0   30               0              3
#
#    Inflight wifi service  Inflight entertainment  Online support  \
# 0                      2                       4               2
# 2                      2                       0               2
# 3                      3                       4               3
# 4                      4                       3               4
# 5                      2                       0               2
#
#    Ease of Online booking  On-board service  Leg room service  \
# 0                       3                 3                 0
# 2                       2                 3                 3
# 3                       1                 1                 0
# 4                       2                 2                 0
# 5                       2                 5                 4
#
#    Baggage handling  Checkin service  Cleanliness  Online boarding  \
# 0                 3                5            3                2
# 2                 4                4            4                2
# 3                 1                4            1                3
# 4                 2                4            2                5
# 5                 5                5            4                2
#
#    Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                           0                       0.0
# 2                           0                       0.0
# 3                           0                       0.0
# 4                           0                       0.0
# 5                           0                       0.0
#
#    Customer Type_disloyal Customer  Type of Travel_Personal Travel  Class_Eco  \
# 0                            False                            True       True
# 2                            False                            True       True
# 3                            False                            True       True
# 4                            False                            True       True
# 5                            False                            True       True
#
#    Class_Eco Plus  Gender_Male
# 0           False        False
# 2           False        False
# 3           False        False
# 4           False        False
# 5           False         True

# %%
#2
fig, ax = plt.subplots()
g = sns.kdeplot(data=df_copy, x="satisfaction", fill=True, hue="Customer Type", ax=ax)
ax.set(title="density of satisfaction for loyal vs disloyal customers")
plt.show()
# Out:
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_cat.groupby(by=['satisfaction']).size()
#get the size of each value of satisfaction column
# Out:
# satisfaction
# 0    40408
# 1    54040
# dtype: int64

# %%
df_cat['partition'] = np.random.choice(['train', 'test'], df_cat.shape[0], p=[0.7, 0.3]) # split the train and test data by 70/30 split percentage
df_train = df_cat[df_cat['partition'] == 'train'] # df_train is equal to df_cat['partition'] when df_cat == train
df_test= df_cat[df_cat['partition'] == 'test'] # df_test is equal to df_cat['partition'] when df_cat == test
 
df_train_1 = df_train[df_train['satisfaction'] == 1] 
df_train_0 = df_train[df_train['satisfaction'] == 0]

under = df_train_1.sample(n=df_train_0.shape[0]) # under sample the majority class to match the minority class
df_train_bal = pd.concat([under, df_train_0]) # combine the undersampled majority and the minority data into one data set

df_train_bal.groupby(by=['satisfaction']).size() # check the size of each type of satisfaction from the balanced dataset"""
# Out:
# satisfaction
# 0    28334
# 1    28334
# dtype: int64

# %%
cols = ['Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes', 'Age'] # continuous variables to be checked for multicollinearity

for var in cols: # for every variable that we have on top, we will go over this process
    output_cols = df_train_bal[[var]] # what is going to be our output (colms)? 1 variable at a time.
    
    input_vars = cols.copy() # copy variables on top
    input_vars.remove(var) # inputs - output variable; just a list
    
    input_cols = df_train_bal[input_vars] # list of all input colms 
    
    lm = LinearRegression() # linear regression model
    lm.fit(input_cols, output_cols) # fit the model
    
    output_pred = lm.predict(input_cols) # predic the output based on the model we built
    
    r2 = r2_score(output_cols, output_pred) # get the r2 value of the output col + output prediction
    print('r-squared of', var, r2)
    print('VIF of', var, 1/(1-r2), '\n')
    
    #output < 4 is OKAY; low probability of collinearity
# Out:
# r-squared of Flight Distance 0.05650725126046707
# VIF of Flight Distance 1.0598915586112967
#
# r-squared of Departure Delay in Minutes 0.19900021682399271
# VIF of Departure Delay in Minutes 1.2484397886288385
#
# r-squared of Arrival Delay in Minutes 0.1977097037163711
# VIF of Arrival Delay in Minutes 1.24643162784369
#
# r-squared of Age 0.05447919889259045
# VIF of Age 1.0576181918248477

# %%
df_train_bal.columns
# Out:
# Index(['satisfaction', 'Flight Distance', 'Seat comfort',
#        'Departure/Arrival time convenient', 'Age', 'Food and drink',
#        'Gate location', 'Inflight wifi service', 'Inflight entertainment',
#        'Online support', 'Ease of Online booking', 'On-board service',
#        'Leg room service', 'Baggage handling', 'Checkin service',
#        'Cleanliness', 'Online boarding', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes', 'Customer Type_disloyal Customer',
#        'Type of Travel_Personal Travel', 'Class_Eco', 'Class_Eco Plus',
#        'Gender_Male', 'partition'],
#       dtype='object')

# %%
var_list = ['Age', 'Flight Distance', 'Seat comfort',
                       'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
                       'Inflight wifi service', 'Inflight entertainment', 'Online support',
                       'Ease of Online booking', 'On-board service', 'Leg room service',
                       'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
                       'Departure Delay in Minutes', 'Arrival Delay in Minutes',
                       'Customer Type_disloyal Customer', 'Type of Travel_Personal Travel',
                       'Class_Eco', 'Class_Eco Plus', 'Gender_Male']

X_train = df_train_bal[['Age', 'Flight Distance', 'Seat comfort',
                       'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
                       'Inflight wifi service', 'Inflight entertainment', 'Online support',
                       'Ease of Online booking', 'On-board service', 'Leg room service',
                       'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
                       'Departure Delay in Minutes', 'Arrival Delay in Minutes',
                       'Customer Type_disloyal Customer', 'Type of Travel_Personal Travel',
                       'Class_Eco', 'Class_Eco Plus', 'Gender_Male']]

Y_train = df_train_bal[['satisfaction']]

# %%
X_test = df_test[['Age', 'Flight Distance', 'Seat comfort',
                       'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
                       'Inflight wifi service', 'Inflight entertainment', 'Online support',
                       'Ease of Online booking', 'On-board service', 'Leg room service',
                       'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
                       'Departure Delay in Minutes', 'Arrival Delay in Minutes',
                       'Customer Type_disloyal Customer', 'Type of Travel_Personal Travel',
                       'Class_Eco', 'Class_Eco Plus', 'Gender_Male']]

Y_test = df_test[['satisfaction']]

# %%
dec_tree = tree.DecisionTreeClassifier(ccp_alpha = 0.008)
dec_tree.fit(X_train, Y_train)

Y_train_pred = dec_tree.predict(X_train)
print(f'Train accuracy is {accuracy_score(Y_train, Y_train_pred)}')
# Out:
# Train accuracy is 0.8568857203359921

# %%
cm = confusion_matrix(Y_train, Y_train_pred)
disp = ConfusionMatrixDisplay(cm, display_labels = dec_tree.classes_).plot();
#[TN, FP]
#[FN, TP]

# %%
print(classification_report(Y_train, Y_train_pred)) #print the classification report
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86     28334
#            1       0.86      0.85      0.86     28334
#
#     accuracy                           0.86     56668
#    macro avg       0.86      0.86      0.86     56668
# weighted avg       0.86      0.86      0.86     56668

# %%
text_representation = tree.export_text(dec_tree, feature_names =var_list) #display the tree representation of the the decision tree
print(text_representation)
# Out:
# |--- Inflight entertainment <= 3.50
# |   |--- Seat comfort <= 3.50
# |   |   |--- Seat comfort <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- Seat comfort >  0.50
# |   |   |   |--- class: 0
# |   |--- Seat comfort >  3.50
# |   |   |--- class: 1
# |--- Inflight entertainment >  3.50
# |   |--- Ease of Online booking <= 3.50
# |   |   |--- Inflight entertainment <= 4.50
# |   |   |   |--- class: 0
# |   |   |--- Inflight entertainment >  4.50
# |   |   |   |--- class: 1
# |   |--- Ease of Online booking >  3.50
# |   |   |--- class: 1

# %%
Y_test_pred = dec_tree.predict(X_test)
print(f'Test_Accuracy is {accuracy_score(Y_test, Y_test_pred)}')
# Out:
# Test_Accuracy is 0.8586697915556976

# %%
cm1 = confusion_matrix(Y_test, Y_test_pred)
disp = ConfusionMatrixDisplay(cm1, display_labels = dec_tree.classes_).plot();

# %%
print(classification_report(Y_test, Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84     12074
#            1       0.90      0.85      0.87     16087
#
#     accuracy                           0.86     28161
#    macro avg       0.86      0.86      0.86     28161
# weighted avg       0.86      0.86      0.86     28161

# %%
df2 = pd.DataFrame({'Variable': X_train.columns, 'Importance': dec_tree.feature_importances_}).sort_values(by=['Importance'], ascending = False)
df2
# Out:
#                              Variable  Importance
# 7              Inflight entertainment    0.695009
# 2                        Seat comfort    0.216502
# 9              Ease of Online booking    0.088489
# 0                                 Age    0.000000
# 13                    Checkin service    0.000000
# 21                     Class_Eco Plus    0.000000
# 20                          Class_Eco    0.000000
# 19     Type of Travel_Personal Travel    0.000000
# 18    Customer Type_disloyal Customer    0.000000
# 17           Arrival Delay in Minutes    0.000000
# 16         Departure Delay in Minutes    0.000000
# 15                    Online boarding    0.000000
# 14                        Cleanliness    0.000000
# 11                   Leg room service    0.000000
# 12                   Baggage handling    0.000000
# 1                     Flight Distance    0.000000
# 10                   On-board service    0.000000
# 8                      Online support    0.000000
# 6               Inflight wifi service    0.000000
# 5                       Gate location    0.000000
# 4                      Food and drink    0.000000
# 3   Departure/Arrival time convenient    0.000000
# 22                        Gender_Male    0.000000

# %%
df3 = pd.DataFrame({'Variable': X_test.columns, 'Importance': dec_tree.feature_importances_}).sort_values(by=['Importance'], ascending = False)
df3
# Out:
#                              Variable  Importance
# 7              Inflight entertainment    0.695009
# 2                        Seat comfort    0.216502
# 9              Ease of Online booking    0.088489
# 0                                 Age    0.000000
# 13                    Checkin service    0.000000
# 21                     Class_Eco Plus    0.000000
# 20                          Class_Eco    0.000000
# 19     Type of Travel_Personal Travel    0.000000
# 18    Customer Type_disloyal Customer    0.000000
# 17           Arrival Delay in Minutes    0.000000
# 16         Departure Delay in Minutes    0.000000
# 15                    Online boarding    0.000000
# 14                        Cleanliness    0.000000
# 11                   Leg room service    0.000000
# 12                   Baggage handling    0.000000
# 1                     Flight Distance    0.000000
# 10                   On-board service    0.000000
# 8                      Online support    0.000000
# 6               Inflight wifi service    0.000000
# 5                       Gate location    0.000000
# 4                      Food and drink    0.000000
# 3   Departure/Arrival time convenient    0.000000
# 22                        Gender_Male    0.000000

# %%
values = df2.Importance    
idx = df2.Variable
plt.figure(figsize=(8,6))
clrs = ['indigo' if (x < max(values)) else 'blue' for x in values ]
sns.barplot(y=idx,x=values,palette=clrs).set(title='Important features to predict satisfaction')
plt.show()
# Out:
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
values = df3.Importance    
idx = df3.Variable
plt.figure(figsize=(8,6))
clrs = ['indigo' if (x < max(values)) else 'blue' for x in values ]
sns.barplot(y=idx,x=values,palette=clrs).set(title='Important features to predict satisfaction')
plt.show()
# Out:
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
fpr, tpr, thresholds = metrics.roc_curve(Y_train, Y_train_pred)
 
#calculating area under the curve(AUC)
roc_auc = metrics.auc(fpr, tpr)
roc_auc

plt.clf()
plt.plot(fpr, tpr, label ="ROC curve (area=%0.2f)" % roc_auc)
plt.plot([0,1], [0,1], 'k--')
plt.legend(loc="lower right")

# %%
from sklearn import datasets, metrics, model_selection, svm

# %%
fpr, tpr, thresholds = metrics.roc_curve(Y_test, Y_test_pred)
 
#calculating area under the curve(AUC)
roc_auc = metrics.auc(fpr, tpr)
roc_auc

plt.clf()
plt.plot(fpr, tpr, label ="ROC curve (area=%0.2f)" % roc_auc)
plt.plot([0,1], [0,1], 'k--')
plt.legend(loc="lower right")

# %%
from sklearn.metrics import roc_auc_score

# %%
score_test = dec_tree.score(X = X_test, y=Y_test)
score_test
# Out:
# 0.8586697915556976

# %%
# Out:
# 0.8568857203359921
