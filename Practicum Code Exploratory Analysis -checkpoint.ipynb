# %%
import pandas as pd
import numpy as np
import openpyxl
pd.set_option('display.max_columns', None)
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import r2_score, confusion_matrix, classification_report, roc_curve, auc, RocCurveDisplay, ConfusionMatrixDisplay
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Invistico_Airline_Original_Copy.csv') # read the data from csv file

# %%
df.info() # understand the data, including the data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  object
#  3   Type of Travel                     129880 non-null  object
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Seat comfort                       129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Age                                129880 non-null  int64
#  9   Food and drink                     129880 non-null  int64
#  10  Gate location                      129880 non-null  int64
#  11  Inflight wifi service              129880 non-null  int64
#  12  Inflight entertainment             129880 non-null  int64
#  13  Online support                     129880 non-null  int64
#  14  Ease of Online booking             129880 non-null  int64
#  15  On-board service                   129880 non-null  int64
#  16  Leg room service                   129880 non-null  int64
#  17  Baggage handling                   129880 non-null  int64
#  18  Checkin service                    129880 non-null  int64
#  19  Cleanliness                        129880 non-null  int64
#  20  Online boarding                    129880 non-null  int64
#  21  Departure Delay in Minutes         129880 non-null  int64
#  22  Arrival Delay in Minutes           129487 non-null  float64
# dtypes: float64(1), int64(17), object(5)
# memory usage: 22.8+ MB

# %%
#check for null values
df.isna().sum()
# Out:
# satisfaction                           0
# Gender                                 0
# Customer Type                          0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Age                                    0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# dtype: int64

# %%
#delete row method because null count is low
df_delete_row = df.dropna(axis=0)

# %%
#validate that null values were removed
df_delete_row.isna().sum(axis=0)
# Out:
# satisfaction                         0
# Gender                               0
# Customer Type                        0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Age                                  0
# Food and drink                       0
# Gate location                        0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Online boarding                      0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %%
df_summary = df_delete_row.describe()

# %%
# determining the name of the file
file_name = "Summary_Stats.xlsx"
 
# saving the excel
df_summary.to_excel(file_name)

# %%
sns.set(style="whitegrid")
sns.countplot(data=df_delete_row, x="satisfaction")
plt.title("Total Count of Satisfied vs Dissatisfied")
plt.show()
# Out:
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.set(style="whitegrid")
sns.countplot(data=df_delete_row, x="satisfaction", hue="Class")
plt.title("Distibution of Satisfaction over Class")
plt.show()
# Out:
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.violinplot(data=df_delete_row, x="satisfaction", y="Age")
plt.title("Distribution of Satisfaction over Age")
plt.show()
# Out:
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.violinplot(data=df_delete_row, x="satisfaction", y="Flight Distance")
plt.title("Distribution of Satisfaction Against Flight Distance")
plt.show()
# Out:
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plot = df_delete_row.plot.pie(y='Class', figsize=(5, 5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 plot = df_delete_row.plot.pie(y='Class', figsize=(5, 5))
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:1661, in PlotAccessor.pie(self, **kwargs)
#    1655 if (
#    1656     isinstance(self._parent, ABCDataFrame)
#    1657     and kwargs.get("y", None) is None
#    1658     and not kwargs.get("subplots", False)
#    1659 ):
#    1660     raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1661 return self(kind="pie", **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:70, in plot(data, kind, **kwargs)
#      68             ax = plt.gca()
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      71 plot_obj.generate()
#      72 plot_obj.draw()
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1826, in PiePlot.__init__(self, data, kind, **kwargs)
#    1824 def __init__(self, data, kind=None, **kwargs) -> None:
#    1825     data = data.fillna(value=0)
# -> 1826     if (data < 0).any().any():
#    1827         raise ValueError(f"{self._kind} plot doesn't allow negative values")
#    1828     MPLPlot.__init__(self, data, kind=kind, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5799, in Series._cmp_method(self, other, op)
#    5796 lvalues = self._values
#    5797 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5799 res_values = ops.comparison_op(lvalues, rvalues, op)
#    5801 return self._construct_result(res_values, name=res_name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:346, in comparison_op(left, right, op)
#     343     return invalid_comparison(lvalues, rvalues, op)
#     345 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 346     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     348 else:
#     349     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:131, in comp_method_OBJECT_ARRAY(op, x, y)
#     129     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     130 else:
# --> 131     result = libops.scalar_compare(x.ravel(), y, op)
#     132 return result.reshape(x.shape)
#
# File ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
#in column 'satisfaction', replace "satisfied" == 1 and "dissatisfied" == 0
df_delete_row['satisfaction'] = df_delete_row['satisfaction'].replace({'satisfied': 1, 'dissatisfied': 0})
df_delete_row.head()
# Out:
# C:\Users\mblus\AppData\Local\Temp\ipykernel_14448\110920926.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_delete_row['satisfaction'] = df_delete_row['satisfaction'].replace({'satisfied': 1, 'dissatisfied': 0})
#    satisfaction  Gender   Customer Type   Type of Travel     Class  \
# 0             1  Female  Loyal Customer  Personal Travel       Eco
# 1             1    Male  Loyal Customer  Personal Travel  Business
# 2             1  Female  Loyal Customer  Personal Travel       Eco
# 3             1  Female  Loyal Customer  Personal Travel       Eco
# 4             1  Female  Loyal Customer  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  Age  \
# 0              265             0                                  0   65
# 1             2464             0                                  0   47
# 2             2138             0                                  0   15
# 3              623             0                                  0   60
# 4              354             0                                  0   70
#
#    Food and drink  Gate location  Inflight wifi service  \
# 0               0              2                      2
# 1               0              3                      0
# 2               0              3                      2
# 3               0              3                      3
# 4               0              3                      4
#
#    Inflight entertainment  Online support  Ease of Online booking  \
# 0                       4               2                       3
# 1                       2               2                       3
# 2                       0               2                       2
# 3                       4               3                       1
# 4                       3               4                       2
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 3                 0                 3                5
# 1                 4                 4                 4                2
# 2                 3                 3                 4                4
# 3                 1                 0                 1                4
# 4                 2                 0                 2                4
#
#    Cleanliness  Online boarding  Departure Delay in Minutes  \
# 0            3                2                           0
# 1            3                2                         310
# 2            4                2                           0
# 3            1                3                           0
# 4            2                5                           0
#
#    Arrival Delay in Minutes
# 0                       0.0
# 1                     305.0
# 2                       0.0
# 3                       0.0
# 4                       0.0

# %%
#
fig, ax = plt.subplots()
g = sns.kdeplot(data=df_delete_row, x="satisfaction", fill=True, hue="Gender", ax=ax)
ax.set(title="density of satisfaction for between men vs women")
plt.show()
# Out:
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#
fig, ax = plt.subplots()
g = sns.kdeplot(data=df_delete_row, x="satisfaction", fill=True, hue="Age", ax=ax)
ax.set(title="density of satisfaction for between men vs women")
plt.show()
# Out:
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#in column 'satisfaction', replace "satisfied" == 1 and "dissatisfied" == 0
df_delete_row['satisfaction'] = df_delete_row['satisfaction'].replace({'satisfied': 1, 'dissatisfied': 0})
df_delete_row.head()
# Out:
# C:\Users\mblus\AppData\Local\Temp\ipykernel_14448\110920926.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_delete_row['satisfaction'] = df_delete_row['satisfaction'].replace({'satisfied': 1, 'dissatisfied': 0})
#    satisfaction  Gender   Customer Type   Type of Travel     Class  \
# 0             1  Female  Loyal Customer  Personal Travel       Eco
# 1             1    Male  Loyal Customer  Personal Travel  Business
# 2             1  Female  Loyal Customer  Personal Travel       Eco
# 3             1  Female  Loyal Customer  Personal Travel       Eco
# 4             1  Female  Loyal Customer  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  Age  \
# 0              265             0                                  0   65
# 1             2464             0                                  0   47
# 2             2138             0                                  0   15
# 3              623             0                                  0   60
# 4              354             0                                  0   70
#
#    Food and drink  Gate location  Inflight wifi service  \
# 0               0              2                      2
# 1               0              3                      0
# 2               0              3                      2
# 3               0              3                      3
# 4               0              3                      4
#
#    Inflight entertainment  Online support  Ease of Online booking  \
# 0                       4               2                       3
# 1                       2               2                       3
# 2                       0               2                       2
# 3                       4               3                       1
# 4                       3               4                       2
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 3                 0                 3                5
# 1                 4                 4                 4                2
# 2                 3                 3                 4                4
# 3                 1                 0                 1                4
# 4                 2                 0                 2                4
#
#    Cleanliness  Online boarding  Departure Delay in Minutes  \
# 0            3                2                           0
# 1            3                2                         310
# 2            4                2                           0
# 3            1                3                           0
# 4            2                5                           0
#
#    Arrival Delay in Minutes
# 0                       0.0
# 1                     305.0
# 2                       0.0
# 3                       0.0
# 4                       0.0

# %%
#detect and eliminate outliers of continuous variables
df_copy = df_delete_row.copy() # copy data for safe keeping
var_list = ['Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes'] #list of variables for cycling through the loop

for var in var_list:
    iqr = df_copy[var_list].quantile(0.75)[var] - df_copy[var_list].quantile(0.25)[var] #establish the iqr by subracting the 25% from 75%
    if not np.isnan(iqr): #if not null, then perform the following
        ub = df_copy[var_list].quantile(0.75)[var] + 1.5*iqr # cal the upper bound
        lb = df_copy[var_list].quantile(0.25)[var] - 1.5*iqr # cal the lower bound
        df_copy = df_copy[(df_copy[var] <= ub) & (df_copy[var] >= lb)] # leave the values that are less than the ub and greater than the lb and resave in df_copy
    
print(df_delete_row.shape)
print(df_copy.shape)
# Out:
# (129487, 23)
# (94448, 23)

# %%
cat_var = ["Customer Type","Type of Travel","Class", "Gender"] #list out all of the categorical variables that need dummy encoding
df_cat = pd.get_dummies(df_copy, columns=cat_var, drop_first=True)
df_cat.head()
# Out:
#    satisfaction  Age  Flight Distance  Seat comfort  \
# 0             1   65              265             0
# 2             1   15             2138             0
# 3             1   60              623             0
# 4             1   70              354             0
# 5             1   30             1894             0
#
#    Departure/Arrival time convenient  Food and drink  Gate location  \
# 0                                  0               0              2
# 2                                  0               0              3
# 3                                  0               0              3
# 4                                  0               0              3
# 5                                  0               0              3
#
#    Inflight wifi service  Inflight entertainment  Online support  \
# 0                      2                       4               2
# 2                      2                       0               2
# 3                      3                       4               3
# 4                      4                       3               4
# 5                      2                       0               2
#
#    Ease of Online booking  On-board service  Leg room service  \
# 0                       3                 3                 0
# 2                       2                 3                 3
# 3                       1                 1                 0
# 4                       2                 2                 0
# 5                       2                 5                 4
#
#    Baggage handling  Checkin service  Cleanliness  Online boarding  \
# 0                 3                5            3                2
# 2                 4                4            4                2
# 3                 1                4            1                3
# 4                 2                4            2                5
# 5                 5                5            4                2
#
#    Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                           0                       0.0
# 2                           0                       0.0
# 3                           0                       0.0
# 4                           0                       0.0
# 5                           0                       0.0
#
#    Customer Type_disloyal Customer  Type of Travel_Personal Travel  Class_Eco  \
# 0                            False                            True       True
# 2                            False                            True       True
# 3                            False                            True       True
# 4                            False                            True       True
# 5                            False                            True       True
#
#    Class_Eco Plus  Gender_Male
# 0           False        False
# 2           False        False
# 3           False        False
# 4           False        False
# 5           False         True

# %%
#2
fig, ax = plt.subplots()
g = sns.kdeplot(data=df_copy, x="satisfaction", fill=True, hue="Customer Type", ax=ax)
ax.set(title="density of satisfaction for loyal vs disloyal customers")
plt.show()

#piggybacking off of figure 1, the density of unpopular shares is high in the share range of about 1000 and for popular news it peaks around 2000.
# Out:
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\mblus\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_cat.groupby(by=['satisfaction']).size()
#get the size of each value of satisfaction column
# Out:
# satisfaction
# 0    40408
# 1    54040
# dtype: int64

# %%
df_cat['partition'] = np.random.choice(['train', 'test'], df_cat.shape[0], p=[0.7, 0.3]) # split the train and test data by 70/30 split percentage
df_train = df_cat[df_cat['partition'] == 'train'] # df_train is equal to df_cat['partition'] when df_cat == train
df_test= df_cat[df_cat['partition'] == 'test'] # df_test is equal to df_cat['partition'] when df_cat == test
 
df_train_1 = df_train[df_train['satisfaction'] == 1] 
df_train_0 = df_train[df_train['satisfaction'] == 0]

under = df_train_1.sample(n=df_train_0.shape[0]) # under sample the majority class to match the minority class
df_train_bal = pd.concat([under, df_train_0]) # combine the undersampled majority and the minority data into one data set

df_train_bal.groupby(by=['satisfaction']).size() # check the size of each type of satisfaction from the balanced dataset
# Out:
# satisfaction
# 0    28391
# 1    28391
# dtype: int64

# %%
cols = ['Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes', 'Age'] # continuous variables to be checked for multicollinearity

for var in cols: # for every variable that we have on top, we will go over this process
    output_cols = df_train_bal[[var]] # what is going to be our output (colms)? 1 variable at a time.
    
    input_vars = cols.copy() # copy variables on top
    input_vars.remove(var) # inputs - output variable; just a list
    
    input_cols = df_train_bal[input_vars] # list of all input colms 
    
    lm = LinearRegression() # linear regression model
    lm.fit(input_cols, output_cols) # fit the model
    
    output_pred = lm.predict(input_cols) # predic the output based on the model we built
    
    r2 = r2_score(output_cols, output_pred) # get the r2 value of the output col + output prediction
    print('r-squared of', var, r2)
    print('VIF of', var, 1/(1-r2), '\n')
    
    #output < 4 is OKAY; low probability of collinearity
# Out:
# r-squared of Flight Distance 0.05459657020251052
# VIF of Flight Distance 1.057749494535053
#
# r-squared of Departure Delay in Minutes 0.19637972657018876
# VIF of Departure Delay in Minutes 1.2443688058441456
#
# r-squared of Arrival Delay in Minutes 0.19527003658279218
# VIF of Arrival Delay in Minutes 1.2426528717205918
#
# r-squared of Age 0.05299644122542113
# VIF of Age 1.055962240832546

# %%
df_train_bal.columns
# Out:
# Index(['satisfaction', 'Age', 'Flight Distance', 'Seat comfort',
#        'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
#        'Inflight wifi service', 'Inflight entertainment', 'Online support',
#        'Ease of Online booking', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'Customer Type_disloyal Customer', 'Type of Travel_Personal Travel',
#        'Class_Eco', 'Class_Eco Plus', 'Gender_Male', 'partition'],
#       dtype='object')

# %%
X_train = df_train_bal[['Age', 'Flight Distance', 'Seat comfort',
                       'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
                       'Inflight wifi service', 'Inflight entertainment', 'Online support',
                       'Ease of Online booking', 'On-board service', 'Leg room service',
                       'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
                       'Departure Delay in Minutes', 'Arrival Delay in Minutes',
                       'Customer Type_disloyal Customer', 'Type of Travel_Personal Travel',
                       'Class_Eco', 'Class_Eco Plus', 'Gender_Male']]

Y_train = df_train_bal[['satisfaction']]

# %%
X_test = df_test[['Age', 'Flight Distance', 'Seat comfort',
                       'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
                       'Inflight wifi service', 'Inflight entertainment', 'Online support',
                       'Ease of Online booking', 'On-board service', 'Leg room service',
                       'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
                       'Departure Delay in Minutes', 'Arrival Delay in Minutes',
                       'Customer Type_disloyal Customer', 'Type of Travel_Personal Travel',
                       'Class_Eco', 'Class_Eco Plus', 'Gender_Male']]

Y_test = df_test[['satisfaction']]
